# %% [markdown]
# # 데이터와 행렬
# ## 연습문제 2.1.1
# NumPy를 사용해서 붓꽃 데이터 x2에 대한 벡터 변수 x2를 만든다.

# %%
import numpy as np
import matplotlib.pylab as plt

from sklearn.datasets import load_iris

iris = load_iris()

# 백터 변수 x2
x2 = iris.data[1, :]

# %%
from sklearn.datasets import load_digits
import matplotlib as mpl

# 한글
mpl.rc('font', family = 'NanumGothic')
mpl.rc('axes', unicode_minus = False)

digits = load_digits()

samples = [0, 10, 20, 30, 1, 11, 21, 31]
d = []
for i in range(8):
    d.append(digits.images[samples[i]]) #sample 번호에 맞는 인덱스의 image를 d 리스트에 추가

plt.figure(figsize=(8, 2))  # 가로 8 세로 2 크기 figure크기

for i in range(8):
    plt.subplot(1, 8, i + 1) # 1행 8열의 plot으로 출력
    plt.imshow(d[i], interpolation = 'nearest', cmap = plt.cm.bone_r)
    plt.grid(False) # 그리드 없음
    plt.xticks([]) # x축 레이어 없음
    plt.yticks([]) # y축 레이어 없음
    plt.title("image {}".format(i + 1)) # 각 figure의 제목 설정
plt.suptitle("숫자 0과 1 이미지") # 전체 figure의 제목 설정
plt.tight_layout() # 레이아웃 자동 맞춤
plt.show()

# %%
v = []
for i in range(8):
    v.append(d[i].reshape(64, 1)) # d 리스트 8X8을 64X1로 1차원 벡터로 변환하여 v에 추가

plt.figure(figsize = (8, 3)) # 가로 8 세로 3  figure 크기
for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.imshow(v[i], aspect = 0.4, interpolation='nearest', cmap = plt.cm.bone_r)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.title('벡터 {}'.format(i + 1))
plt.suptitle('벡터화된 이미지', y = 1.05) # figure 제목의 y 위치
plt.tight_layout(w_pad = 7) # 인접한 subplot 사이의 너비 7 설정
plt.show()

# %% [markdown]
# ## 연습문제 2.1.2
# 넘파이를 사용해서 붓꽃 데이터 X에 대한 행렬 변수 X를 만든다.

# %%
from sklearn.datasets import load_iris  # 사이킷런 패키지 임포트
import numpy as np

iris = load_iris()  # 데이터 로드

# 붓꽃 데이터 X에 대한 행렬 변수 X
X = np.array(iris.data)

# %%
from scipy import misc 
img_rgb = misc.face()
img_rgb.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# 한글
mpl.rc('font', family = 'NanumGothic')
mpl.rc('axes', unicode_minus = False)

plt.subplot(221) # 2행 2열의 첫번째
plt.imshow(img_rgb, cmap = plt.cm.gray)
plt.axis('off')
plt.title('RGB 컬러 이미지')

plt.subplot(222)
plt.imshow(img_rgb[:,:, 0], cmap = plt.cm.gray)
plt.axis('off')
plt.title('Red 채널')

plt.subplot(223)
plt.imshow(img_rgb[:, :, 1], cmap = plt.cm.gray)
plt.axis('off')
plt.title('Green 채널')

plt.subplot(224)
plt.imshow(img_rgb[:, :, 2], cmap = plt.cm.gray)
plt.axis('off')
plt.title('Blue 채널')

plt.show()

# %% [markdown]
# ## 연습문제 2.1.3
#
# 1. NumPy를 사용해서 붓꽃 데이터 X의 전치행렬 XT을 구한다.
#
# 2. NumPy를 사용해서 위 전치행렬을 다시 전치한 행렬 (XT)T을 구한다. 이 행렬과 원래 행렬 X을 비교한다.

# %%
# X의 전치 행렬 X_T
X_T = X.T

# X_T의 전치 행렬 X_T_T
X_T_T = X_T.T

# X_T의 전치 행렬과 X는 동일하다.

# %% [markdown]
# ## 연습문제 2.1.4
#
# 영벡터, 일벡터, 정방행렬, 대각행렬, 항등행렬, 대칭행렬의 예를 하나씩 만들어본다.
#
# 위의 벡터와 행렬을 NumPy로 나타내 본다.

# %%
import numpy as np

# 영벡터
X_1 = np.zeros((5, 1))

# 일벡터
X_2 = np.ones((5, 1))

# 정방행렬
X_3 = np.array([[0, 0, 0], [1, 1, 1], [2, 2, 2]])

# 대각 행렬
X_4 = np.diag([1, 2, 3])
X_5 = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3], [0, 0, 0]])

# 항등행렬
X_6 = np.identity(4)
X_7 = np.eye(4)

# 대칭행렬
X_8 = np.array([[1, 2, 3, 4], [2, 1, 2, 3], [3, 2, 1, 2], [4, 3, 2, 1]])

# %% [markdown]
# ## 연습문제 2.2.1
#
# A, B, C 세 회사의 주식은 각각 100만원, 80만원, 50만원이다. 이 주식을 각각 3주, 4주, 5주를 매수할 때 필요한 금액을 구하고자 한다.
#
# (1) 주식의 가격과 수량을 각각 p 벡터, n 벡터로 표시하고 넘파이로 코딩한다.
#
# (2) 주식을 매수할 때 필요한 금액을 곱셈으로 표시하고 넘파이 연산으로 그 값을 계산한다.

# %%
import numpy as np

# 주식의 가격
p = np.array([100, 80, 50])

# 주식의 수량
n = np.array([3, 4, 5])

# 주식을 매수할 때 필요한 금액
money = p.T @ n

# %% [markdown]
# ## 0과 1을 나타내는 MNIST 이미지에 대한 내적 계산

# %%
from sklearn.datasets import load_digits
import matplotlib.gridspec as gridspec

digits = load_digits()
d1 = digits.images[0]
d2 = digits.images[10]
d3 = digits.images[1]
d4 = digits.images[11]

v1 = d1.reshape(64, 1)
v2 = d2.reshape(64, 1)
v3 = d3.reshape(64, 1)
v4 = d4.reshape(64, 1)

# figure의 크기 설정
plt.figure(figsize = (9, 9))

# 그리드 1행 8열에 높이와 너비 비율 설정
gs = gridspec.GridSpec(1, 8, height_ratios=[1], width_ratios=[9, 1, 9, 1, 9, 1, 9, 1])

for i in range(4):
    plt.subplot(gs[2 * i])
    plt.imshow(eval('d' + str(i + 1)), aspect = 1, interpolation='nearest', cmap = plt.cm.bone_r)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.title('image {}'.format(i + 1))
    plt.subplot(gs[2 * i + 1])
    plt.imshow(eval('v' + str(i + 1)), aspect= 0.25, interpolation= 'nearest', cmap = plt.cm.bone_r)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.title('vector {}'.format(i + 1))

plt.tight_layout()
plt.show()

# %%
(v1.T @ v2)[0][0], (v3.T @ v4)[0][0]
# Out:
# (3064.0, 3661.0)

# %%
(v1.T @ v3)[0][0], (v1.T @ v4)[0][0], (v2.T @ v3)[0][0], (v2.T @ v4)[0][0]
# Out:
# (1866.0, 1883.0, 2421.0, 2479.0)

# %% [markdown]
# ## 연습문제 2.2.3
#
# 다음 코드를 실행하면 MNIST 숫자 이미지 전체 데이터를 모두 벡터로 변환하여 하나의 넘파이 행렬 X를 만든다. 이 행렬을 이용하여 다음 문제를 풀어라.
#
# (1) 내적을 이용하여 첫 번째 이미지와 10번째 이미지의 유사도를 구하라.
#
# (2) 내적을 이용하여 모든 이미지의 조합에 대해 유사도를 구하라. 어떻게 구현하는 것이 효율적일까? (힌트 : 이 문제는 뒤에서 배울 행렬과 행렬의 곱셈을 이용한다.)

# %%
from sklearn.datasets import load_digits
X = load_digits().data

# 문제 1
# 64 X 1 열 벡터로 첫번째 이미지 변환
image_1 = X[0].reshape(64, 1)

# 64 X 1 열 벡터로 10번째 이미지 변환
image_10 = X[9].reshape(64, 1)

# 유사도 구하기 2807.0
(image_1.T @ image_10)[0][0]


# 문제 2 
# 전치행렬과 내적 곱을 하면 모든 이미지의 조합에 대해 유사도를 구할 수 있다.
X @ X.T
# Out:
# 2807.0

# %% [markdown]
# ## 연습문제 2.2.4
#
# (1) A와 B가 위와 같을 때 AB를 연습장에 손으로 계산하고 넘파이의 계산 결과와 맞는지 확인한다.
#
# (2) 순서를 바꾸어 BA를 손으로 계산하고 넘파이의 계산 결과와 맞는지 확인한다. BA가 AB와 같은가?
#
# (3) A, B가 다음과 같을 때, AB, BA를 (계산이 가능하다면) 손으로 계산하고 넘파이의 계산 결과와 맞는지 확인한다. AB, BA 모두 계산 가능한가?

# %%
from sklearn.datasets import load_iris
X = load_iris().data

one = np.ones(150)

X_bar = ((X @ one) @ one.T) / 150



X_bar

# len(X_bar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-9f87d093268b> in <module>
#       4 one = np.ones(150)
#       5
# ----> 6 X_bar = ((X @ one) @ one.T) / 150
#       7
#       8
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 150 is different from 4)
